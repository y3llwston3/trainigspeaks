# %% [markdown]
# # Get Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.graph_objects as go
import plotly.express as px 
import datetime
import csv

# %% [markdown]
# # Read files

# %%
files = pd.read_csv('/Users/apple/Documents/Jupyter/own project/Lukas trainigspeaks/workouts.csv')
files.head()
# Out:
#      Title WorkoutType WorkoutDescription  PlannedDuration  \
# 0  Running         Run                NaN              NaN
# 1  Running         Run                NaN              NaN
# 2  Cycling        Bike                NaN              NaN
# 3  Cycling        Bike                NaN              NaN
# 4  Running         Run                NaN              NaN
#
#    PlannedDistanceInMeters  WorkoutDay CoachComments  DistanceInMeters  \
# 0                      NaN  2022-01-13           NaN       5197.740234
# 1                      NaN  2022-01-20           NaN       5419.120117
# 2                      NaN  2022-01-22           NaN      26354.960938
# 3                      NaN  2022-01-23           NaN      56560.769531
# 4                      NaN  2022-01-23           NaN       5333.229980
#
#    PowerAverage  PowerMax  ...  PWRZone3Minutes  PWRZone4Minutes  \
# 0           NaN       NaN  ...              NaN              NaN
# ...

# %%
import pandas as pd

# Read the CSV file
#df = pd.read_csv('/Users/apple/Documents/Jupyter/own project/Lukas trainigspeaks/workouts.csv')

# Define a list of WorkoutTypes to exclude
#exclude_types = ['Bike', 'Swim', 'Other', 'Day Off', 'Strength']

# Filter out the rows that contain any of the exclude_types
#df = df[~df['WorkoutType'].isin(exclude_types)].reset_index(drop=True)

# Save the filtered dataframe to a new CSV file
#df.to_csv('filtered_file.csv', index=False)

# %%
# read run files
run = pd.read_csv('/Users/apple/Documents/Jupyter/own project/Lukas trainigspeaks/filtered_file.csv')
run.head()
# Out:
#      Title WorkoutType WorkoutDescription  PlannedDuration  \
# 0  Running         Run                NaN              NaN
# 1  Running         Run                NaN              NaN
# 2  Running         Run                NaN              NaN
# 3  Running         Run                NaN              NaN
# 4  Running         Run                NaN              NaN
#
#    PlannedDistanceInMeters  WorkoutDay CoachComments  DistanceInMeters  \
# 0                      NaN  2022-01-13           NaN       5197.740234
# 1                      NaN  2022-01-20           NaN       5419.120117
# 2                      NaN  2022-01-23           NaN       5333.229980
# 3                      NaN  2022-01-26           NaN       8375.589844
# 4                      NaN  2022-01-30           NaN       7580.180176
#
#    PowerAverage  PowerMax  ...  PWRZone3Minutes  PWRZone4Minutes  \
# 0           NaN       NaN  ...              NaN              NaN
# ...

# %%
run.columns
# Out:
# Index(['Title', 'WorkoutType', 'WorkoutDescription', 'PlannedDuration',
#        'PlannedDistanceInMeters', 'WorkoutDay', 'CoachComments',
#        'DistanceInMeters', 'PowerAverage', 'PowerMax', 'Energy',
#        'AthleteComments', 'TimeTotalInHours', 'VelocityAverage', 'VelocityMax',
#        'CadenceAverage', 'CadenceMax', 'HeartRateAverage', 'HeartRateMax',
#        'TorqueAverage', 'TorqueMax', 'IF', 'TSS', 'HRZone1Minutes',
#        'HRZone2Minutes', 'HRZone3Minutes', 'HRZone4Minutes', 'HRZone5Minutes',
#        'HRZone6Minutes', 'HRZone7Minutes', 'HRZone8Minutes', 'HRZone9Minutes',
#        'HRZone10Minutes', 'PWRZone1Minutes', 'PWRZone2Minutes',
#        'PWRZone3Minutes', 'PWRZone4Minutes', 'PWRZone5Minutes',
#        'PWRZone6Minutes', 'PWRZone7Minutes', 'PWRZone8Minutes',
#        'PWRZone9Minutes', 'PWRZone10Minutes', 'Rpe', 'Feeling'],
#       dtype='object')

# %%
#drop a bunch of colmns

columns_to_drop = ["WorkoutDescription","PlannedDistanceInMeters","PWRZone6Minutes",
                   "PWRZone7Minutes","PWRZone8Minutes","PWRZone9Minutes","PWRZone10Minutes",
                   "CoachComments","AthleteComments", "VelocityMax","CadenceMax","TorqueMax","TorqueAverage",
                   "HRZone6Minutes","HRZone7Minutes","HRZone8Minutes","HRZone9Minutes","HRZone10Minutes",
                   "PWRZone1Minutes","PWRZone2Minutes","PWRZone3Minutes","PWRZone4Minutes","PWRZone5Minutes",
                   "PWRZone6Minutes","PWRZone7Minutes","PWRZone8Minutes","PWRZone9Minutes","PWRZone10Minutes",
                  "PlannedDuration","PowerMax","PowerAverage"]       
                   


run.drop(columns_to_drop, axis = 1, inplace= True)


                   
run.head()
# Out:
#      Title WorkoutType  WorkoutDay  DistanceInMeters  Energy  \
# 0  Running         Run  2022-01-13       5197.740234     NaN
# 1  Running         Run  2022-01-20       5419.120117     NaN
# 2  Running         Run  2022-01-23       5333.229980     NaN
# 3  Running         Run  2022-01-26       8375.589844     NaN
# 4  Running         Run  2022-01-30       7580.180176     NaN
#
#    TimeTotalInHours  VelocityAverage  CadenceAverage  HeartRateAverage  \
# 0          0.500093            2.887            78.0             147.0
# 1          0.506274            2.973            77.0             154.0
# 2          0.501100            2.956            76.0             160.0
# 3          0.731567            3.180            77.0             158.0
# 4          0.717272            2.936            76.0             160.0
#
#    HeartRateMax        IF    TSS  HRZone1Minutes  HRZone2Minutes  \
# 0         158.0  0.669317  24.39            13.0            17.0
# ...

# %% [markdown]
# # Analysing Data

# %%
# Creation of correlatoion matrix
corr = run.loc[:,run.dtypes == 'float64'].corr()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, 
            cmap=sns.diverging_palette(220, 10, as_cmap=True))
# Out:
# <Axes: >

# %%
plt.scatter(run.HeartRateAverage, run.TSS)
plt.xlabel('Heart Rate Avg')
plt.ylabel('TSS')
plt.show()

# %%
# Plot Heart Rate and TSS
plt.scatter(run.TimeTotalInHours, run.DistanceInMeters)
plt.xlim(0, 1.2) 
plt.ylim(0, 15000)# set the x-axis limits to 0-2 hours
plt.xlabel('Time (hours)')
plt.ylabel('Distance (meters)')
plt.show()

# %%
# Plot Time and Heart Rate Average
plt.scatter(run.TimeTotalInHours, run.HeartRateAverage)
plt.xlim(0, 3)  # set the x-axis limits to 0-3 hours
plt.xlabel('Time (hours)')
plt.ylabel('Heart Rate Average')
plt.show()
